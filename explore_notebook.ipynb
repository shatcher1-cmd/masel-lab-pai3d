# %%
import gzip

# %%
with gzip.open("/home/shatcher1/projects/PrimateAI-3D/data/PrimateAI-3D.hg38.chr22.txt.gz", "rt") as f:
    for i, line in enumerate(f):
        print(line.strip())
        if i == 4:
            break
# Out:
# chr	pos	non_flipped_ref	non_flipped_alt	gene_name	change_position_1based	ref_aa	alt_aa	score_PAI3D	percentile_PAI3D	refseq	prediction
# chr22	15528162	T	A	ENST00000252835.5	2	C	S	0.2581238429248332	0.0510291963772975	NM_001005239.1	benign
# chr22	15528162	T	C	ENST00000252835.5	2	C	R	0.3413320681452751	0.131647737305311	NM_001005239.1	benign
# chr22	15528162	T	G	ENST00000252835.5	2	C	G	0.3433631609007715	0.13402699341165	NM_001005239.1	benign
# chr22	15528163	G	A	ENST00000252835.5	2	C	Y	0.3644637966156006	0.1595568461447308	NM_001005239.1	benign

# %%
VCF_PATH = "/home/shatcher1/projects/PrimateAI-3D/data/1000g/1kGP_high_coverage_Illumina.chr22.filtered.SNV_INDEL_SV_phased_panel.vcf.gz"

with gzip.open(VCF_PATH, "rt") as f:
    for i, line in enumerate(f):
        if line.startswith("##"):
            continue
        if line.startswith("#CHROM"):
            fields = line.strip().split("\t")
            print("Header:")
            print(fields[:9])
            continue

        fields = line.strip().split("\t")
        print("\n First Row of Data:")
        print(fields[:9])
        break
# Out:
# Header:
# ['#CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT']
#
#  First Row of Data:
# ['chr22', '10519265', '22:10519265:CA:C', 'CA', 'C', '.', '.', 'AC=2;AF=0.000312305;CM=0;AN=6404;AN_EAS=1170;AN_AMR=980;AN_EUR=1266;AN_AFR=1786;AN_SAS=1202;AN_EUR_unrel=1006;AN_EAS_unrel=1008;AN_AMR_unrel=694;AN_SAS_unrel=978;AN_AFR_unrel=1322;AF_EAS=0;AF_AMR=0.00204082;AF_EUR=0;AF_AFR=0;AF_SAS=0;AF_EUR_unrel=0;MAF_EUR_unrel=0;AF_EAS_unrel=0;MAF_EAS_unrel=0;AF_AMR_unrel=0.00144092;MAF_AMR_unrel=0.00144092;AF_SAS_unrel=0;MAF_SAS_unrel=0;AF_AFR_unrel=0;MAF_AFR_unrel=0;AC_EAS=0;AC_AMR=2;AC_EUR=0;AC_AFR=0;AC_SAS=0;AC_EUR_unrel=0;AC_EAS_unrel=0;AC_AMR_unrel=1;AC_SAS_unrel=0;AC_AFR_unrel=0;AC_Het_EAS=0;AC_Het_AMR=2;AC_Het_EUR=0;AC_Het_AFR=0;AC_Het_SAS=0;AC_Het_EUR_unrel=0;AC_Het_EAS_unrel=0;AC_Het_AMR_unrel=1;AC_Het_SAS_unrel=0;AC_Het_AFR_unrel=0;AC_Het=2;AC_Hom_EAS=0;AC_Hom_AMR=0;AC_Hom_EUR=0;AC_Hom_AFR=0;AC_Hom_SAS=0;AC_Hom_EUR_unrel=0;AC_Hom_EAS_unrel=0;AC_Hom_AMR_unrel=0;AC_Hom_SAS_unrel=0;AC_Hom_AFR_unrel=0;AC_Hom=0;HWE_EAS=1;ExcHet_EAS=1;HWE_AMR=1;ExcHet_AMR=0.998979;HWE_EUR=1;ExcHet_EUR=1;HWE_AFR=1;ExcHet_AFR=1;HWE_SAS=1;ExcHet_SAS=1;HWE=1;ExcHet=0.999844', 'GT']
